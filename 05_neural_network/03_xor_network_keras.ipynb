# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import h5py
import numpy as np
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.optimizers import SGD

# %%
# Our example for an exclusive OR.
X_train = np.array([[0, 0],
                    [0, 1],
                    [1, 0],
                    [1, 1]])
y_train = np.array([[0],
                    [1],
                    [1],
                    [0]])

# %%
model = Sequential()
num_neurons = 10
model.add(Dense(num_neurons, input_dim=2))
model.add(Activation('tanh'))
model.add(Dense(1))
model.add(Activation('sigmoid'))
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_8 (Dense)              (None, 10)                30
# _________________________________________________________________
# activation_8 (Activation)    (None, 10)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 11
# _________________________________________________________________
# activation_9 (Activation)    (None, 1)                 0
# ...
# Total params: 41
# Trainable params: 41
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Stochastic gradient descent optimizer.
# Higher learning rate (lr) will speed up learning, but may force model away from the global minimum by shooting past the goal.
sgd = SGD(lr=.1)
model.compile(loss='binary_crossentropy',
              optimizer=sgd,
              metrics=['accuracy'])
model.predict(X_train)
# Out:
# array([[0.5       ],
#        [0.27400053],
#        [0.2987333 ],
#        [0.15720485]], dtype=float32)

# %%
model.fit(X_train, y_train, epochs=1000)
# Out:
# Train on 4 samples
# Epoch 1/1000
# 4/4 [==============================] - 0s 19ms/sample - loss: 0.8418 - accuracy: 0.5000
# Epoch 2/1000
# 4/4 [==============================] - 0s 959us/sample - loss: 0.8207 - accuracy: 0.2500
# Epoch 3/1000
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.8030 - accuracy: 0.2500
# Epoch 4/1000
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.7881 - accuracy: 0.2500
# Epoch 5/1000
# 4/4 [==============================] - 0s 1ms/sample - loss: 0.7756 - accuracy: 0.2500
# Epoch 6/1000
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.7651 - accuracy: 0.2500
# Epoch 7/1000
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.7563 - accuracy: 0.2500
# Epoch 8/1000
# 4/4 [==============================] - 0s 3ms/sample - loss: 0.7489 - accuracy: 0.2500
# Epoch 9/1000
# 4/4 [==============================] - 0s 2ms/sample - loss: 0.7426 - accuracy: 0.2500
# Epoch 10/1000
# ...

# %%
model.predict_classes(X_train)
# Out:
# array([[0],
#        [1],
#        [1],
#        [0]], dtype=int32)

# %%
model.predict(X_train)
# Out:
# array([[0.01536676],
#        [0.9632126 ],
#        [0.96425825],
#        [0.04218585]], dtype=float32)

# %%
model_structure = model.to_json()
with open('basic_model.json', 'w') as f:
    f.write(model_structure)

# %%
model.save_weights('basic_weights.h5')

# %%
# !ls -a
# Out:
# .                          03_xor_network_keras.ipynb
# ..                         04_mnist.ipynb
# .ipynb_checkpoints         basic_model.json
# 01_basic_neuron.ipynb      basic_weights.h5
# 02_or_gate.ipynb

# %%
# !cat basic_model.json
# Out:
# {"class_name": "Sequential", "config": {"name": "sequential_4", "layers": [{"class_name": "Dense", "config": {"name": "dense_8", "trainable": true, "batch_input_shape": [null, 2], "dtype": "float32", "units": 10, "activation": "linear", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": null, "activity_regularizer": null, "kernel_constraint": null, "bias_constraint": null}}, {"class_name": "Activation", "config": {"name": "activation_8", "trainable": true, "dtype": "float32", "activation": "tanh"}}, {"class_name": "Dense", "config": {"name": "dense_9", "trainable": true, "dtype": "float32", "units": 1, "activation": "linear", "use_bias": true, "kernel_initializer": {"class_name": "GlorotUniform", "config": {"seed": null}}, "bias_initializer": {"class_name": "Zeros", "config": {}}, "kernel_regularizer": null, "bias_regularizer": nul
# ...

# %% [markdown]
# ## Summary
#
# - the network "learn" by minimizing the cost function through backpropagation
# - the amount a weight contributes to a model's error is directly related to the amount it needs to be updated
# - neural network are optimization engines
